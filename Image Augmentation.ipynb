# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy import misc, ndimage
# %matplotlib inline

from keras.preprocessing.image import ImageDataGenerator
# Out:
# Using TensorFlow backend.

# %%
#function used to plot on jupyter notebook

def plots(ims, figsize=(12,6), rows=1, interp=False, titles=None):
    if type(ims[0]) is np.ndarray:
        ims = np.array(ims).astype(np.uint8)
        if (ims.shape[-1] != 3):
            ims = ims.transpose((0,2,3,1))
    f = plt.figure(figsize = figsize)
    cols = len(ims)//rows if len(ims) % 2 == 0 else len(ims)//rows+1
    for i in range(len(ims)):
        sp = f.add_subplot(rows, cols, i+1)
        sp.axis('Off')
        if titles is not None:
            sp.set_title(titles[i], fontsize=10)
            
        plt.imshow(ims[i], interpolation = None if interp else 'none')

# %%
#generation of the augmented images 
gen = ImageDataGenerator(rotation_range=10, width_shift_range = 0.1,
                        height_shift_range=0.1, shear_range=0.15,
                        zoom_range = 0.1, channel_shift_range=10., horizontal_flip=True)

# %%
#paths for each person in the training set
image_path_1 = 'GT_train/s1/s01_02.jpg'
image_path_2 = 'GT_train/s2/s02_02.jpg'
image_path_3 = 'GT_train/s3/s03_02.jpg'
image_path_4 = 'GT_train/s4/s04_02.jpg'
image_path_5 = 'GT_train/s5/s05_02.jpg'
image_path_6 = 'GT_train/s6/s06_02.jpg'
image_path_7 = 'GT_train/s7/s07_02.jpg'
image_path_8 = 'GT_train/s8/s08_02.jpg'
image_path_9 = 'GT_train/s9/s09_02.jpg'
image_path_10 = 'GT_train/s10/s10_02.jpg'

# %%
#reading the images from their paths
image_1 = np.expand_dims(ndimage.imread(image_path_1),0)
image_2 = np.expand_dims(ndimage.imread(image_path_2),0)
image_3 = np.expand_dims(ndimage.imread(image_path_3),0)
image_4 = np.expand_dims(ndimage.imread(image_path_4),0)
image_5 = np.expand_dims(ndimage.imread(image_path_5),0)
image_6 = np.expand_dims(ndimage.imread(image_path_6),0)
image_7 = np.expand_dims(ndimage.imread(image_path_7),0)
image_8 = np.expand_dims(ndimage.imread(image_path_8),0)
image_9 = np.expand_dims(ndimage.imread(image_path_9),0)
image_10 = np.expand_dims(ndimage.imread(image_path_10),0)

plt.imshow(image[0])
# Out:
# c:\users\me\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0.
# Use ``matplotlib.pyplot.imread`` instead.
#   """Entry point for launching an IPython kernel.
# c:\users\me\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0.
# Use ``matplotlib.pyplot.imread`` instead.
#
# c:\users\me\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0.
# Use ``matplotlib.pyplot.imread`` instead.
#   This is separate from the ipykernel package so we can avoid doing imports until
# c:\users\me\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:4: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0.
# ...

# %%
#setting the augmentation images to be saved in their 
#corresponding training directories  

aug_iter_1 = gen.flow(image_1, save_to_dir='GT_train/s1', save_prefix='aug', save_format='jpg')
aug_iter_2 = gen.flow(image_2, save_to_dir='GT_train/s2', save_prefix='aug', save_format='jpg')
aug_iter_3 = gen.flow(image_3, save_to_dir='GT_train/s3', save_prefix='aug', save_format='jpg')
aug_iter_4 = gen.flow(image_4, save_to_dir='GT_train/s4', save_prefix='aug', save_format='jpg')
aug_iter_5 = gen.flow(image_5, save_to_dir='GT_train/s5', save_prefix='aug', save_format='jpg')
aug_iter_6 = gen.flow(image_6, save_to_dir='GT_train/s6', save_prefix='aug', save_format='jpg')
aug_iter_7 = gen.flow(image_7, save_to_dir='GT_train/s7', save_prefix='aug', save_format='jpg')
aug_iter_8 = gen.flow(image_8, save_to_dir='GT_train/s8', save_prefix='aug', save_format='jpg')
aug_iter_9 = gen.flow(image_9, save_to_dir='GT_train/s9', save_prefix='aug', save_format='jpg')
aug_iter_10 = gen.flow(image_10, save_to_dir='GT_train/s10', save_prefix='aug', save_format='jpg')

# %%
#applying the augmentation

aug_images_1 = [next(aug_iter_1)[0].astype(np.uint8) for i in range(10)]
aug_images_2 = [next(aug_iter_2)[0].astype(np.uint8) for i in range(10)]
aug_images_3 = [next(aug_iter_3)[0].astype(np.uint8) for i in range(10)]
aug_images_4 = [next(aug_iter_4)[0].astype(np.uint8) for i in range(10)]
aug_images_5 = [next(aug_iter_5)[0].astype(np.uint8) for i in range(10)]
aug_images_6 = [next(aug_iter_6)[0].astype(np.uint8) for i in range(10)]
aug_images_7 = [next(aug_iter_7)[0].astype(np.uint8) for i in range(10)]
aug_images_8 = [next(aug_iter_8)[0].astype(np.uint8) for i in range(10)]
aug_images_9 = [next(aug_iter_9)[0].astype(np.uint8) for i in range(10)]
aug_images_10 = [next(aug_iter_10)[0].astype(np.uint8) for i in range(10)]

# %%
#example showing the result of the augmentation
plots(aug_images, figsize=(20,7), rows=2)
